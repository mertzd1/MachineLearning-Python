# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\donal\\Desktop\\Python Programming Course'

# %%
movies=pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns= ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info() #see that two columns have been recognized as an object and 4 in int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Genre.cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-1de508ae4d85> in <module>
# ----> 1 movies.Genre.cat.categories
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, data)
#    2489
#    2490     def __init__(self, data):
# -> 2491         self._validate(data)
#    2492         self._parent = data.values
#    2493         self._index = data.index
#
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in _validate(data)
#    2498     def _validate(data):
#    2499         if not is_categorical_dtype(data.dtype):
# -> 2500             raise AttributeError("Can only use .cat accessor with a "
#    2501                                  "'category' dtype")
#    2502
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
movies.describe() #it does not make sense to have year as a number, we need to change it to a catagories
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info() #now our data set is prepared
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# ------

# %%
from  matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Joint Plots

# %%
j = sns.jointplot(data= movies, x= 'CriticRating', y= 'AudienceRating')

# %%
j = sns.jointplot(data= movies, x= 'CriticRating', y= 'AudienceRating',kind= 'hex')

# %%
#<<<Chart 1

# %% [markdown]
# ----

# %%
#Histograms

# %%
#already know this method:
m1=sns.distplot(movies.AudienceRating, bins=15)

# %%
m2=sns.distplot(movies.CriticRating, bins=15)

# %%
#>>>>Chart 2
sns.set_style("darkgrid")
n1=plt.hist(movies.AudienceRating, bins=15)

# %%
#Chart 3

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
plt.hist(movies[movies.Genre=='Action'].BudgetMillions)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
          movies[movies.Genre=='Drama'].BudgetMillions,\
          movies[movies.Genre=='Thriller'].BudgetMillions,\
          movies[movies.Genre=='Comedy'].BudgetMillions],
          bins=15, stacked =True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
for gen in movies.Genre.cat.categories: #created a loop to put in the above code.
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.set_style("darkgrid")
list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)
h=plt.hist(list1, bins=30, stacked=True, label=mylabels )
plt.legend()
plt.show()

# %%
#<<<<Chart 4

# %%
vis1= sns.lmplot(data=movies, x='CriticRating', y= 'AudienceRating',\
                fit_reg=False, hue="Genre", \
                height=6, aspect=1)    #****size has been renamed to height****

# %%
sns.set_style("darkgrid")
kl=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
               shade=True, shade_lowest=False, cmap="Reds")

#Tip adding both these codes make the chart smoother

klb=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                cmap="Reds")

# %%
#Working with Subplots()

# %%
sns.set_style("darkgrid")
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
sns.set_style("darkgrid")
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, axes=plt.subplots (2,2)
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,1])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1,0])

#this is how you change location of the subplots 1,0: 1,1: 0,0 etc

# %%
f, axes=plt.subplots (1,2, figsize=(10,10), sharex=True, sharey=True) #sharex makes it so I dont have to copy K2.set(xlim=-20,160)
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#ViolinPlots

# %%
w = sns.boxplot(data=movies, x="Genre", y= "CriticRating")

# %%
z = sns.violinplot(data=movies, x="Genre", y= "CriticRating")

# %%
#Creating a Facet Grid

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue="Genre")

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year', hue="Genre")
g=g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
#can poplulate with any type of chart. Example Histograms
g=sns.FacetGrid(movies, row='Genre', col='Year', hue="Genre")
g=g.map(plt.hist, "BudgetMillions")

# %%
#back to the scatter plots
g=sns.FacetGrid(movies, row='Genre', col='Year', hue="Genre")
kws=dict(s=50, edgecolor='black')
g=g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws)

# %%
#Controlling axis and adding diagnols
g=sns.FacetGrid(movies, row='Genre', col='Year', hue="Genre")
kws=dict(s=50, edgecolor='black')
g=g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c="gray", ls="--")
g.add_legend()

# %%
#<<<<Chart 5

# %% [markdown]
# --------

# %%
#Building Dashbards

# %%
from  matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("darkgrid")
f, axes=plt.subplots(2,2, figsize=(15,15))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,\
               ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
               ax=axes[0,1])

z = sns.violinplot(data=movies, x="Year", y= "BudgetMillions", ax=axes[1,0])
sns.set_style("darkgrid")

k4=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
               shade=True, shade_lowest=False, cmap="Reds", ax=axes[1,1])

k4b=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                cmap="Reds", ax=axes[1,1])

#axes[1,1].hist(movies.AudienceRating, bins=15) #becuase it wasn't a sns plot we had to put the ax=axes first
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# _-----

# %%
#Styling Dashboard

# %%
from  matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("dark", {'axes.facecolor':"black"})
f, axes=plt.subplots(2,2, figsize=(15,15))
#Plot 0,0
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,\
               shade=True, shadelowest=True, cmap="inferno",\
               ax=axes[0,0])
#this line added an outline
k1b=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,\
                cmap="cool", ax=axes[0,0])
#Plot 0,1
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
               shade=True, shadelowest=True, cmap="inferno",\
               ax=axes[0,1])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, \
               cmap="cool", ax=axes[0,1])
#Plot 1,0
z = sns.violinplot(data=movies, x="Year", y= "BudgetMillions", ax=axes[1,0],\
                  palette='YlOrRd')
sns.set_style("darkgrid")

#Plot 1,1
k4=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
               shade=True, shade_lowest=False, cmap="Blues_r", ax=axes[1,1])

k4b=sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                cmap="gist_gray_r", ax=axes[1,1])

#axes[1,1].hist(movies.AudienceRating, bins=15) #becuase it wasn't a sns plot we had to put the ax=axes first
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ------

# %%
#Thematic Edits

# %%
list1=list()
mylabels=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    mylabels.append(gen)

sns.set_style("whitegrid") 
fig, ax=plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper
h=plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)
plt.title("Movie Budget Distribution", fontsize=35,\
         color="DarkBlue", fontname="Arial")
plt.ylabel("Number of Movies", fontsize=25, color="Red")
plt.xlabel("Budget", fontsize=25, color="Green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True,fancybox=True, shadow=True, \
           framealpha=1, prop={"size":20})
plt.show()
